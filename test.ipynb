# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_parquet("banking_data/loans_2018.parquet", engine="fastparquet")
df.head()
# Out:
#           loan_id        customer_id  account_id      loan_type  \
# 0   BR20180107553        COM18000001  ACC0040496  Business Loan
# 1    LN2018143375  SUB-COM18000002-4  ACC0040497  Business Loan
# 2  DL-2018-000003        COM18000003  ACC0040495  Business Loan
# 3  DL-2018-000004  SUB-COM18000004-4  ACC0040494  Business Loan
# 4    LN2018954528        IND18000003  ACC0013959  Personal Loan
#
#    principal_amount  amount_granted  interest_rate  terms_months  \
# 0       11484131.05      5785725.04          15.58            36
# 1         510846.83       332773.78          10.57            48
# 2       25105909.31     14827753.11          11.50            48
# 3        5009889.88      3711144.99          10.00            48
# 4           1008.93          690.57          19.00            12
#
#    monthly_installment collateral_description  ...  \
# 0            202211.26    Accounts Receivable  ...
# 1              8531.39              Equipment  ...
# ...
