# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_parquet(r"C:\Users\takue\Documents\GithubUploads\Datasets-Final\insurance_data\insurance_policies.parquet")
df.columns
# Out:
# Index(['Policy_Number', 'Applicant_ID', 'Policy_Type', 'Policy_Subtype',
#        'Coverage_Amount', 'Premium_Amount', 'Deductible_Amount', 'Has_XOL',
#        'Is_Reinsured', 'Reinsurance_Company', 'Reinsurance_Share',
#        'XOL_Retention_Amount', 'Reinsurance_Type', 'Risk_Factor',
#        'Effective_Date', 'Expiration_Date', 'Renewal_Notice_Date',
#        'Payment_Frequency', 'Discount_Percentage', 'Agent_Name', 'Channel',
#        'Policy_Status'],
#       dtype='object')
